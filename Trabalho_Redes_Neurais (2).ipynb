# %% [markdown]
# # Rede Neural para Acidentes em uma Usina Nuclear

# %% [markdown]
# ## Bibliotecas usadas na implementação da rede

# %%
import numpy as np # será usada para mexer com vetores e matrizes
import pandas as pd # será usada para mexer com o arquivo Excel
import matplotlib.pyplot as plt # será usada para mostrar os gráficos desejados
from sklearn.preprocessing import MinMaxScaler # será usada para normalizar os dados do Excel
from sklearn.preprocessing import LabelBinarizer # será usada para transformar os acidentes em binários
from sklearn.model_selection import train_test_split # será usada para dividir o conjunto de dados do arquivo Excel
from tensorflow import random 
from tensorflow.keras import layers, models, optimizers # será usada na construção da rede

seed = 1
np.random.seed(seed)
random.set_seed(seed)

# %% [markdown]
# ## Abrindo o arquivo Excel para leitura

# %%
dados = pd.read_excel("/content/sample_data/dados_trabalho.xlsx")

# %% [markdown]
# ## Selecionando os dados de entrada/saída

# %%
entradas = dados.iloc[:,0:17]
saidas = dados.iloc[:,-1]

# %% [markdown]
# ## Selecionando os dados que serão usados para treinamento, teste e validação

# %%
entradasTreino, entradasTeste, saidasTreino, saidasTeste = train_test_split(entradas, saidas, test_size=0.2)
entradasTreino, entradasValid, saidasTreino, saidasValid = train_test_split(entradasTreino, saidasTreino, test_size=0.2)
print("Quantidade de entradas para treinamento da rede: ", len(entradasTreino))
print("Quantidade de entradas para teste da rede: ", len(entradasTeste))
print("Quantidade de entradas para validação dade rede: ", len(entradasValid))
# Out:
# Quantidade de entradas para treinamento da rede:  468
# Quantidade de entradas para teste da rede:  147
# Quantidade de entradas para validação dade rede:  117

# %% [markdown]
# ## Normalizando os dados de entrada e transformando os nomes dos acidentes em números binários

# %%
normalizer = MinMaxScaler(feature_range = (0, 1))
entradasTreino = normalizer.fit_transform(entradasTreino)
entradasValid = normalizer.transform(entradasValid)
entradasTeste = normalizer.transform(entradasTeste)

lb = LabelBinarizer()
saidasTreino = lb.fit_transform(saidasTreino)
saidasValid = lb.transform(saidasValid)
saidasTeste = lb.transform(saidasTeste)

# %% [markdown]
# ## Definindo as quantidades de entradas, saídas, neurônios, funções de ativação, tipo de otimizador, função erro, tamanho do batch e o número de épocas

# %%
quant_entradas = entradasTreino.shape[1]
quant_saidas = saidasTreino.shape[1]
quant_neuronios = 30
funcaoAtivacao = "sigmoid"
funcaoSaida = "softmax"
optimizer = optimizers.Adam(lr=0.005, beta_1=0.9, beta_2=0.999, epsilon=1E-8, decay=0.0)
funcaoErro ='categorical_crossentropy'
batelada = 50
epocas =  400

# %% [markdown]
# ## Estrutrando a rede

# %%
model = models.Sequential()
# Camada de entrada e camada escondida 1
model.add(layers.Dense(quant_neuronios, activation=funcaoAtivacao, input_dim=quant_entradas))
# Camada Escondida 2
model.add(layers.Dense(quant_neuronios, activation=funcaoAtivacao))
# Camada de Saída
model.add(layers.Dense(quant_saidas, activation=funcaoSaida))

# %% [markdown]
# ## Compilando a rede neural

# %%
model.compile(loss=funcaoErro, optimizer=optimizer)

# %% [markdown]
# ## Treinando a rede neural

# %%
history = model.fit(entradasTreino, saidasTreino, epochs=epocas, batch_size=batelada, validation_data=(entradasValid, saidasValid), shuffle=True,
          verbose=1)
# Out:
# Epoch 1/400
# 10/10 [==============================] - 0s 14ms/step - loss: 1.4037 - val_loss: 1.3867
# Epoch 2/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3562 - val_loss: 1.3042
# Epoch 3/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2967 - val_loss: 1.2490
# Epoch 4/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2294 - val_loss: 1.1653
# Epoch 5/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1591 - val_loss: 1.0619
# Epoch 6/400
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0528 - val_loss: 0.9623
# Epoch 7/400
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9605 - val_loss: 0.8615
# Epoch 8/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8758 - val_loss: 0.7854
# Epoch 9/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8063 - val_loss: 0.7194
# Epoch 10/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7538 - val_loss: 0.6671
# Epoch 11/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7093 - val_loss: 0.6273
# Epoch 12/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6818 - val_loss: 0.5967
# Epoch 13/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6572 - val_loss: 0.5726
# Epoch 14/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6351 - val_loss: 0.5510
# Epoch 15/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6240 - val_loss: 0.5298
# Epoch 16/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6057 - val_loss: 0.5148
# Epoch 17/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5941 - val_loss: 0.4994
# Epoch 18/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5796 - val_loss: 0.4869
# Epoch 19/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5716 - val_loss: 0.4705
# Epoch 20/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5632 - val_loss: 0.4641
# Epoch 21/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5528 - val_loss: 0.4504
# Epoch 22/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5566 - val_loss: 0.4531
# Epoch 23/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5434 - val_loss: 0.4376
# Epoch 24/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5398 - val_loss: 0.4370
# Epoch 25/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5342 - val_loss: 0.4226
# Epoch 26/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5266 - val_loss: 0.4221
# Epoch 27/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5174 - val_loss: 0.4130
# Epoch 28/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5256 - val_loss: 0.4077
# Epoch 29/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5176 - val_loss: 0.4112
# Epoch 30/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5134 - val_loss: 0.4066
# Epoch 31/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5070 - val_loss: 0.4016
# Epoch 32/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5098 - val_loss: 0.3980
# Epoch 33/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5057 - val_loss: 0.3941
# Epoch 34/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5054 - val_loss: 0.3978
# Epoch 35/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5000 - val_loss: 0.3924
# Epoch 36/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5024 - val_loss: 0.3962
# Epoch 37/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4923 - val_loss: 0.3917
# Epoch 38/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4905 - val_loss: 0.3887
# Epoch 39/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4894 - val_loss: 0.3867
# Epoch 40/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4905 - val_loss: 0.3826
# Epoch 41/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5004 - val_loss: 0.3818
# Epoch 42/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4946 - val_loss: 0.3863
# Epoch 43/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4915 - val_loss: 0.3845
# Epoch 44/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4781 - val_loss: 0.3801
# Epoch 45/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4830 - val_loss: 0.3764
# Epoch 46/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4762 - val_loss: 0.3759
# Epoch 47/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4762 - val_loss: 0.3795
# Epoch 48/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4740 - val_loss: 0.3743
# Epoch 49/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4769 - val_loss: 0.3800
# Epoch 50/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4801 - val_loss: 0.3732
# Epoch 51/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4758 - val_loss: 0.3730
# Epoch 52/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4799 - val_loss: 0.3768
# Epoch 53/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4809 - val_loss: 0.3757
# Epoch 54/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4768 - val_loss: 0.3726
# Epoch 55/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4685 - val_loss: 0.3716
# Epoch 56/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4682 - val_loss: 0.3748
# Epoch 57/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4685 - val_loss: 0.3686
# Epoch 58/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4728 - val_loss: 0.3754
# Epoch 59/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4638 - val_loss: 0.3719
# Epoch 60/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4686 - val_loss: 0.3683
# Epoch 61/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4636 - val_loss: 0.3714
# Epoch 62/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4659 - val_loss: 0.3673
# Epoch 63/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4629 - val_loss: 0.3699
# Epoch 64/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4622 - val_loss: 0.3679
# Epoch 65/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4599 - val_loss: 0.3712
# Epoch 66/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4609 - val_loss: 0.3676
# Epoch 67/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4632 - val_loss: 0.3680
# Epoch 68/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4561 - val_loss: 0.3685
# Epoch 69/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4583 - val_loss: 0.3666
# Epoch 70/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4625 - val_loss: 0.3651
# Epoch 71/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4556 - val_loss: 0.3706
# Epoch 72/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4553 - val_loss: 0.3675
# Epoch 73/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4604 - val_loss: 0.3630
# Epoch 74/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4588 - val_loss: 0.3682
# Epoch 75/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4555 - val_loss: 0.3637
# Epoch 76/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4583 - val_loss: 0.3638
# Epoch 77/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4531 - val_loss: 0.3612
# Epoch 78/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4496 - val_loss: 0.3667
# Epoch 79/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4524 - val_loss: 0.3585
# Epoch 80/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4486 - val_loss: 0.3649
# Epoch 81/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4475 - val_loss: 0.3601
# Epoch 82/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4474 - val_loss: 0.3608
# Epoch 83/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4508 - val_loss: 0.3611
# Epoch 84/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4540 - val_loss: 0.3565
# Epoch 85/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4523 - val_loss: 0.3653
# Epoch 86/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4468 - val_loss: 0.3561
# Epoch 87/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4474 - val_loss: 0.3631
# Epoch 88/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4432 - val_loss: 0.3623
# Epoch 89/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4488 - val_loss: 0.3613
# Epoch 90/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4475 - val_loss: 0.3559
# Epoch 91/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4489 - val_loss: 0.3591
# Epoch 92/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4520 - val_loss: 0.3558
# Epoch 93/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4407 - val_loss: 0.3694
# Epoch 94/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4423 - val_loss: 0.3590
# Epoch 95/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4425 - val_loss: 0.3541
# Epoch 96/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4402 - val_loss: 0.3541
# Epoch 97/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4349 - val_loss: 0.3619
# Epoch 98/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4411 - val_loss: 0.3534
# Epoch 99/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4379 - val_loss: 0.3553
# Epoch 100/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4359 - val_loss: 0.3637
# Epoch 101/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4330 - val_loss: 0.3513
# Epoch 102/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4376 - val_loss: 0.3589
# Epoch 103/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4320 - val_loss: 0.3662
# Epoch 104/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4332 - val_loss: 0.3531
# Epoch 105/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4359 - val_loss: 0.3588
# Epoch 106/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4315 - val_loss: 0.3569
# Epoch 107/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4352 - val_loss: 0.3607
# Epoch 108/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4330 - val_loss: 0.3533
# Epoch 109/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4280 - val_loss: 0.3671
# Epoch 110/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4342 - val_loss: 0.3522
# Epoch 111/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4284 - val_loss: 0.3544
# Epoch 112/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4265 - val_loss: 0.3510
# Epoch 113/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4271 - val_loss: 0.3567
# Epoch 114/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4247 - val_loss: 0.3544
# Epoch 115/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4223 - val_loss: 0.3555
# Epoch 116/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4328 - val_loss: 0.3602
# Epoch 117/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4270 - val_loss: 0.3544
# Epoch 118/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4237 - val_loss: 0.3592
# Epoch 119/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4224 - val_loss: 0.3549
# Epoch 120/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4194 - val_loss: 0.3519
# Epoch 121/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4213 - val_loss: 0.3509
# Epoch 122/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4204 - val_loss: 0.3481
# Epoch 123/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4197 - val_loss: 0.3519
# Epoch 124/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4173 - val_loss: 0.3505
# Epoch 125/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4175 - val_loss: 0.3579
# Epoch 126/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4170 - val_loss: 0.3508
# Epoch 127/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4173 - val_loss: 0.3502
# Epoch 128/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4141 - val_loss: 0.3518
# Epoch 129/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4155 - val_loss: 0.3565
# Epoch 130/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4138 - val_loss: 0.3494
# Epoch 131/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4133 - val_loss: 0.3533
# Epoch 132/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4148 - val_loss: 0.3498
# Epoch 133/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4112 - val_loss: 0.3536
# Epoch 134/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4133 - val_loss: 0.3565
# Epoch 135/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4109 - val_loss: 0.3544
# Epoch 136/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4175 - val_loss: 0.3497
# Epoch 137/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4078 - val_loss: 0.3619
# Epoch 138/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4121 - val_loss: 0.3498
# Epoch 139/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4083 - val_loss: 0.3518
# Epoch 140/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4078 - val_loss: 0.3534
# Epoch 141/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4102 - val_loss: 0.3526
# Epoch 142/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4132 - val_loss: 0.3489
# Epoch 143/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4110 - val_loss: 0.3575
# Epoch 144/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4116 - val_loss: 0.3499
# Epoch 145/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4122 - val_loss: 0.3567
# Epoch 146/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4167 - val_loss: 0.3552
# Epoch 147/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4049 - val_loss: 0.3482
# Epoch 148/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4072 - val_loss: 0.3511
# Epoch 149/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4053 - val_loss: 0.3557
# Epoch 150/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4037 - val_loss: 0.3475
# Epoch 151/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4042 - val_loss: 0.3527
# Epoch 152/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4011 - val_loss: 0.3425
# Epoch 153/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4039 - val_loss: 0.3512
# Epoch 154/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4010 - val_loss: 0.3472
# Epoch 155/400
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4054 - val_loss: 0.3548
# Epoch 156/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4024 - val_loss: 0.3498
# Epoch 157/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4017 - val_loss: 0.3588
# Epoch 158/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4004 - val_loss: 0.3497
# Epoch 159/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4036 - val_loss: 0.3563
# Epoch 160/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4002 - val_loss: 0.3481
# Epoch 161/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4033 - val_loss: 0.3554
# Epoch 162/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3978 - val_loss: 0.3471
# Epoch 163/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4000 - val_loss: 0.3543
# Epoch 164/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3957 - val_loss: 0.3533
# Epoch 165/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3964 - val_loss: 0.3530
# Epoch 166/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3966 - val_loss: 0.3481
# Epoch 167/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3951 - val_loss: 0.3497
# Epoch 168/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3958 - val_loss: 0.3423
# Epoch 169/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3939 - val_loss: 0.3492
# Epoch 170/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3950 - val_loss: 0.3433
# Epoch 171/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3980 - val_loss: 0.3489
# Epoch 172/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3959 - val_loss: 0.3449
# Epoch 173/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3917 - val_loss: 0.3501
# Epoch 174/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3930 - val_loss: 0.3449
# Epoch 175/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3942 - val_loss: 0.3538
# Epoch 176/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3997 - val_loss: 0.3412
# Epoch 177/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3975 - val_loss: 0.3377
# Epoch 178/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3980 - val_loss: 0.3434
# Epoch 179/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3938 - val_loss: 0.3526
# Epoch 180/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4020 - val_loss: 0.3392
# Epoch 181/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3998 - val_loss: 0.3472
# Epoch 182/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3915 - val_loss: 0.3414
# Epoch 183/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3880 - val_loss: 0.3538
# Epoch 184/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3866 - val_loss: 0.3362
# Epoch 185/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3862 - val_loss: 0.3516
# Epoch 186/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3862 - val_loss: 0.3464
# Epoch 187/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3859 - val_loss: 0.3448
# Epoch 188/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3893 - val_loss: 0.3373
# Epoch 189/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3863 - val_loss: 0.3418
# Epoch 190/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3884 - val_loss: 0.3300
# Epoch 191/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3903 - val_loss: 0.3435
# Epoch 192/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3839 - val_loss: 0.3365
# Epoch 193/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3864 - val_loss: 0.3417
# Epoch 194/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4049 - val_loss: 0.3343
# Epoch 195/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3912 - val_loss: 0.3301
# Epoch 196/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3873 - val_loss: 0.3451
# Epoch 197/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3874 - val_loss: 0.3438
# Epoch 198/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3821 - val_loss: 0.3233
# Epoch 199/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3817 - val_loss: 0.3489
# Epoch 200/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3811 - val_loss: 0.3280
# Epoch 201/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3795 - val_loss: 0.3378
# Epoch 202/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3791 - val_loss: 0.3365
# Epoch 203/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3782 - val_loss: 0.3257
# Epoch 204/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3762 - val_loss: 0.3353
# Epoch 205/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3792 - val_loss: 0.3370
# Epoch 206/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3775 - val_loss: 0.3269
# Epoch 207/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3745 - val_loss: 0.3299
# Epoch 208/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3764 - val_loss: 0.3299
# Epoch 209/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3729 - val_loss: 0.3281
# Epoch 210/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3796 - val_loss: 0.3352
# Epoch 211/400
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3759 - val_loss: 0.3254
# Epoch 212/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3747 - val_loss: 0.3194
# Epoch 213/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3709 - val_loss: 0.3334
# Epoch 214/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3782 - val_loss: 0.3125
# Epoch 215/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3691 - val_loss: 0.3373
# Epoch 216/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3793 - val_loss: 0.3157
# Epoch 217/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3766 - val_loss: 0.3290
# Epoch 218/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3748 - val_loss: 0.3364
# Epoch 219/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3672 - val_loss: 0.3144
# Epoch 220/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3707 - val_loss: 0.3205
# Epoch 221/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3656 - val_loss: 0.3284
# Epoch 222/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3671 - val_loss: 0.3148
# Epoch 223/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3624 - val_loss: 0.3186
# Epoch 224/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3629 - val_loss: 0.3306
# Epoch 225/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3784 - val_loss: 0.3234
# Epoch 226/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3882 - val_loss: 0.3221
# Epoch 227/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3773 - val_loss: 0.3099
# Epoch 228/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3677 - val_loss: 0.3165
# Epoch 229/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3709 - val_loss: 0.3186
# Epoch 230/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3625 - val_loss: 0.3198
# Epoch 231/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3676 - val_loss: 0.3265
# Epoch 232/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3796 - val_loss: 0.3330
# Epoch 233/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3625 - val_loss: 0.3132
# Epoch 234/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3595 - val_loss: 0.3113
# Epoch 235/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3578 - val_loss: 0.3166
# Epoch 236/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3571 - val_loss: 0.3057
# Epoch 237/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3590 - val_loss: 0.3073
# Epoch 238/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3578 - val_loss: 0.3177
# Epoch 239/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3538 - val_loss: 0.3022
# Epoch 240/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3725 - val_loss: 0.3213
# Epoch 241/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3584 - val_loss: 0.3125
# Epoch 242/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3578 - val_loss: 0.3105
# Epoch 243/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3514 - val_loss: 0.3006
# Epoch 244/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3525 - val_loss: 0.3095
# Epoch 245/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3501 - val_loss: 0.2943
# Epoch 246/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3462 - val_loss: 0.3041
# Epoch 247/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3449 - val_loss: 0.2934
# Epoch 248/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3582 - val_loss: 0.2997
# Epoch 249/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3613 - val_loss: 0.3043
# Epoch 250/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3517 - val_loss: 0.3106
# Epoch 251/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3542 - val_loss: 0.2811
# Epoch 252/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3390 - val_loss: 0.2977
# Epoch 253/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3393 - val_loss: 0.2932
# Epoch 254/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3429 - val_loss: 0.3278
# Epoch 255/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3433 - val_loss: 0.3021
# Epoch 256/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3438 - val_loss: 0.3378
# Epoch 257/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3519 - val_loss: 0.3105
# Epoch 258/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3370 - val_loss: 0.3065
# Epoch 259/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3363 - val_loss: 0.2811
# Epoch 260/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3311 - val_loss: 0.2853
# Epoch 261/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3380 - val_loss: 0.2983
# Epoch 262/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3297 - val_loss: 0.2881
# Epoch 263/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3305 - val_loss: 0.2740
# Epoch 264/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3315 - val_loss: 0.2971
# Epoch 265/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3301 - val_loss: 0.2845
# Epoch 266/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3279 - val_loss: 0.2655
# Epoch 267/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3311 - val_loss: 0.2897
# Epoch 268/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3440 - val_loss: 0.3017
# Epoch 269/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3646 - val_loss: 0.2923
# Epoch 270/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3473 - val_loss: 0.2765
# Epoch 271/400
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3247 - val_loss: 0.2844
# Epoch 272/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3316 - val_loss: 0.2735
# Epoch 273/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3345 - val_loss: 0.2869
# Epoch 274/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3242 - val_loss: 0.2573
# Epoch 275/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3154 - val_loss: 0.2872
# Epoch 276/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3169 - val_loss: 0.2627
# Epoch 277/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3155 - val_loss: 0.2704
# Epoch 278/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3117 - val_loss: 0.2728
# Epoch 279/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3141 - val_loss: 0.2660
# Epoch 280/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3161 - val_loss: 0.3316
# Epoch 281/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3396 - val_loss: 0.2781
# Epoch 282/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3141 - val_loss: 0.2595
# Epoch 283/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3099 - val_loss: 0.2778
# Epoch 284/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3137 - val_loss: 0.2491
# Epoch 285/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3249 - val_loss: 0.2581
# Epoch 286/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3249 - val_loss: 0.3131
# Epoch 287/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3204 - val_loss: 0.2690
# Epoch 288/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3107 - val_loss: 0.2585
# Epoch 289/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3010 - val_loss: 0.2590
# Epoch 290/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3053 - val_loss: 0.2679
# Epoch 291/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3025 - val_loss: 0.2669
# Epoch 292/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3123 - val_loss: 0.2485
# Epoch 293/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3002 - val_loss: 0.2695
# Epoch 294/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2925 - val_loss: 0.2348
# Epoch 295/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3005 - val_loss: 0.2544
# Epoch 296/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3019 - val_loss: 0.2762
# Epoch 297/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2955 - val_loss: 0.2516
# Epoch 298/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2919 - val_loss: 0.2529
# Epoch 299/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2989 - val_loss: 0.2523
# Epoch 300/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3008 - val_loss: 0.2381
# Epoch 301/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2944 - val_loss: 0.2495
# Epoch 302/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2880 - val_loss: 0.2643
# Epoch 303/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2883 - val_loss: 0.2313
# Epoch 304/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2958 - val_loss: 0.2301
# Epoch 305/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2960 - val_loss: 0.2470
# Epoch 306/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2998 - val_loss: 0.2357
# Epoch 307/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2856 - val_loss: 0.2437
# Epoch 308/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3057 - val_loss: 0.2422
# Epoch 309/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3039 - val_loss: 0.2506
# Epoch 310/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2880 - val_loss: 0.2519
# Epoch 311/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2812 - val_loss: 0.2404
# Epoch 312/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2769 - val_loss: 0.2410
# Epoch 313/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2768 - val_loss: 0.2259
# Epoch 314/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2739 - val_loss: 0.2209
# Epoch 315/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2931 - val_loss: 0.2272
# Epoch 316/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2778 - val_loss: 0.2341
# Epoch 317/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2944 - val_loss: 0.2334
# Epoch 318/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2719 - val_loss: 0.2422
# Epoch 319/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2915 - val_loss: 0.2260
# Epoch 320/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2657 - val_loss: 0.2339
# Epoch 321/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2753 - val_loss: 0.2381
# Epoch 322/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2873 - val_loss: 0.2979
# Epoch 323/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2859 - val_loss: 0.2734
# Epoch 324/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2964 - val_loss: 0.2238
# Epoch 325/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2673 - val_loss: 0.2404
# Epoch 326/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2752 - val_loss: 0.2376
# Epoch 327/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2664 - val_loss: 0.2181
# Epoch 328/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2627 - val_loss: 0.2162
# Epoch 329/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2972 - val_loss: 0.2786
# Epoch 330/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2629 - val_loss: 0.2218
# Epoch 331/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2574 - val_loss: 0.2049
# Epoch 332/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2566 - val_loss: 0.2187
# Epoch 333/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2513 - val_loss: 0.2097
# Epoch 334/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2605 - val_loss: 0.2073
# Epoch 335/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2515 - val_loss: 0.2129
# Epoch 336/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2499 - val_loss: 0.2702
# Epoch 337/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2634 - val_loss: 0.2219
# Epoch 338/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2459 - val_loss: 0.1927
# Epoch 339/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2555 - val_loss: 0.2065
# Epoch 340/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2515 - val_loss: 0.2142
# Epoch 341/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2494 - val_loss: 0.1941
# Epoch 342/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2423 - val_loss: 0.2148
# Epoch 343/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2423 - val_loss: 0.2118
# Epoch 344/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2458 - val_loss: 0.1988
# Epoch 345/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2412 - val_loss: 0.2010
# Epoch 346/400
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2545 - val_loss: 0.1977
# Epoch 347/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.1975
# Epoch 348/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2435 - val_loss: 0.2189
# Epoch 349/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2468 - val_loss: 0.2369
# Epoch 350/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2462 - val_loss: 0.2164
# Epoch 351/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2475 - val_loss: 0.2351
# Epoch 352/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2507 - val_loss: 0.2036
# Epoch 353/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2341 - val_loss: 0.2055
# Epoch 354/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2386 - val_loss: 0.1832
# Epoch 355/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2275 - val_loss: 0.2045
# Epoch 356/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2333 - val_loss: 0.2441
# Epoch 357/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2470 - val_loss: 0.2046
# Epoch 358/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2310 - val_loss: 0.2121
# Epoch 359/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2371 - val_loss: 0.2120
# Epoch 360/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2483 - val_loss: 0.2047
# Epoch 361/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2352 - val_loss: 0.1854
# Epoch 362/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2455 - val_loss: 0.1865
# Epoch 363/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2417 - val_loss: 0.1892
# Epoch 364/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2225 - val_loss: 0.2043
# Epoch 365/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2233 - val_loss: 0.1836
# Epoch 366/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2188 - val_loss: 0.1984
# Epoch 367/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2207 - val_loss: 0.1868
# Epoch 368/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2240 - val_loss: 0.1976
# Epoch 369/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2313 - val_loss: 0.2094
# Epoch 370/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2384 - val_loss: 0.1851
# Epoch 371/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2195 - val_loss: 0.1782
# Epoch 372/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2186 - val_loss: 0.1834
# Epoch 373/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2181 - val_loss: 0.1783
# Epoch 374/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2191 - val_loss: 0.1845
# Epoch 375/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2109 - val_loss: 0.2023
# Epoch 376/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2079 - val_loss: 0.1860
# Epoch 377/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2333 - val_loss: 0.1757
# Epoch 378/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2219 - val_loss: 0.1843
# Epoch 379/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2146 - val_loss: 0.1784
# Epoch 380/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2146 - val_loss: 0.1717
# Epoch 381/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2083 - val_loss: 0.1785
# Epoch 382/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2054 - val_loss: 0.1820
# Epoch 383/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2115 - val_loss: 0.2046
# Epoch 384/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2190 - val_loss: 0.1826
# Epoch 385/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2209 - val_loss: 0.1835
# Epoch 386/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2137 - val_loss: 0.1686
# Epoch 387/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2279 - val_loss: 0.1802
# Epoch 388/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2119 - val_loss: 0.1705
# Epoch 389/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2102 - val_loss: 0.1894
# Epoch 390/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2163 - val_loss: 0.1744
# Epoch 391/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2033 - val_loss: 0.1865
# Epoch 392/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2292 - val_loss: 0.1871
# Epoch 393/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2003 - val_loss: 0.2578
# Epoch 394/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2341 - val_loss: 0.2829
# Epoch 395/400
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2769 - val_loss: 0.1729
# Epoch 396/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2212 - val_loss: 0.1678
# Epoch 397/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2076 - val_loss: 0.1679
# Epoch 398/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2011 - val_loss: 0.1629
# Epoch 399/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1950 - val_loss: 0.1699
# Epoch 400/400
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2125 - val_loss: 0.1793

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'][0:400])
plt.plot(history.history['val_loss'][0:400])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Convertendo os resultados binários para o nome dos acidentes

# %%
saidasPrevistas = model.predict(entradasTeste)

# %%
# Convertendo os resultados das saídas previstas para 0 e 1
for i in range(len(saidasPrevistas)):
  for j in range(len(saidasPrevistas[0])):
    saidasPrevistas[i][j] = round(saidasPrevistas[i][j],0)

# Convertendo os números binários para o nome dos acidentes correspondentes
saidasPrevistas = list(saidasPrevistas)
saidasTeste = list(saidasTeste)
for i in range(len(saidasPrevistas)):
    if saidasPrevistas[i][0] == 1:
      saidasPrevistas[i] = 'blacksem'
    elif saidasPrevistas[i][1] == 1:
      saidasPrevistas[i] = 'mefwisem'
    elif saidasPrevistas[i][2] == 1:
      saidasPrevistas[i] = 'mfwbr'
    elif saidasPrevistas[i][3] == 1:
      saidasPrevistas[i] = 'mfwisem'

for i in range(len(saidasTeste)):
    if saidasTeste[i][0] == 1:
      saidasTeste[i] = 'blacksem'
    elif saidasTeste[i][1] == 1:
      saidasTeste[i] = 'mefwisem'
    elif saidasTeste[i][2] == 1:
      saidasTeste[i] = 'mfwbr'
    elif saidasTeste[i][3] == 1:
      saidasTeste[i] = 'mfwisem'

# %% [markdown]
# ## Criando listas 'acidentes' e 'quantidade de acidentes' para os conjuntos 'previsto' e 'teste'

# %%
acidentes = ['blacksem','mefwisem','mfwbr','mfwisem']
acidentes_prev = [0,0,0,0]
for i in range(len(saidasPrevistas)):
  if saidasPrevistas[i] in acidentes:
    if saidasPrevistas[i] == 'blacksem':
      acidentes_prev[0] += 1
    elif saidasPrevistas[i] == 'mefwisem':
      acidentes_prev[1] += 1
    elif saidasPrevistas[i] == 'mfwbr':
      acidentes_prev[2] += 1
    elif saidasPrevistas[i] == 'mfwisem':
      acidentes_prev[3] += 1
      
acidentes_teste = [0,0,0,0]
for i in range(len(saidasTeste)):
  if saidasTeste[i] in acidentes:
    if saidasTeste[i] == 'blacksem':
      acidentes_teste[0] += 1
    elif saidasTeste[i] == 'mefwisem':
      acidentes_teste[1] += 1
    elif saidasTeste[i] == 'mfwbr':
      acidentes_teste[2] += 1
    elif saidasTeste[i] == 'mfwisem':
      acidentes_teste[3] += 1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Avaliando resultados

# %%
acertos = 0
for i in range(len(saidasTeste)):
  if saidasTeste[i] == saidasPrevistas[i]:
    acertos += 1
porcent = (acertos/len(saidasTeste))*100
print("Porcentagem de acertos: %f %%" %porcent)
# Out:
# Porcentagem de acertos: 89.115646 %
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig, (graf1, graf2) = plt.subplots(1, 2, figsize=(10,5))
graf1.bar(acidentes, acidentes_prev)
graf1.grid('True')
graf2.bar(acidentes, acidentes_teste)
graf2.grid('True')
graf1.set(title='Acidentes Previstos', xlabel='Acidentes', ylabel='Quantidade')
graf2.set(title='Acidentes Teste', xlabel='Acidentes', ylabel='Quantidade')
# Out:
# [Text(0, 0.5, 'Quantidade'),
#  Text(0.5, 0, 'Acidentes'),
#  Text(0.5, 1.0, 'Acidentes Teste')]
